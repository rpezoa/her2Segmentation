# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

# %%
gs = np.load("/home/rpezoa/experiment_data/big_2+/labels/2+_8.npy")
pred = np.load("/home/rpezoa/Downloads/0_big_pred.npy")
cm =np.load("/home/rpezoa/Downloads/0_cm.npy")

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.reshape(pred,(1000,1000)),cmap="gray")
plt.show()

# %%
# con under_sampling
pred2 = np.load("/home/rpezoa/experiment_data/output/2+_8_rpr_halton_patches/deep_0/big_pred/0_big_pred.npy")
cm2 = np.load("/home/rpezoa/experiment_data/output/2+_8_rpr_halton_patches/deep/cm/0_cm.npy")

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.reshape(pred2,(1000,1000)),cmap="gray")
plt.show()

# %%
print(cm)
print(cm2)
# Out:
# [[972021   8475]
#  [ 14053   5451]]
# [[954567  25929]
#  [  8578  10926]]

# %%
print(f1_score(gs,pred),accuracy_score(gs,pred),precision_score(gs,pred),recall_score(gs,pred))
# Out:
# 0.326114268621 0.977472 0.391426109436 0.279481132075

# %%
print(f1_score(gs,pred2),accuracy_score(gs,pred2), precision_score(gs,pred2), recall_score(gs,pred))
# Out:
# 0.392969963056 0.95465 0.265904644591 0.279481132075

# %%
f1 0.359815998753
rec 0.236618129614
prec 0.750650618087
roc 0.61752731761

# %%
gs.sum()
# Out:
# 19504

# %%
pred.sum()
# Out:
# 13926

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.reshape(gs,(1000,1000)),cmap="gray")
plt.show()

# %%
# con under_sampling
pred2 = np.load("/home/rpezoa/0_big_pred.npy")
plt.figure(figsize=(10,10))
plt.imshow(np.reshape(pred2,(1000,1000)),cmap="gray")
plt.show()

# %%
# con under_sampling
pred2 = np.load("/home/rpezoa/0_big_pred.npy")
plt.figure(figsize=(10,10))
plt.imshow(np.reshape(pred2,(1000,1000)),cmap="gray")
plt.show()

# %%
# con under_sampling
idx_0 = np.load("/home/rpezoa/experiment_data/output/1+_20_rpr_stratified_random/idx_training_pixels/0_0.npy")

idx_1 = np.load("/home/rpezoa/experiment_data/output/1+_20_rpr_stratified_random/idx_training_pixels/0_1.npy")

# %%
print(idx_0.max(), idx_0.min())
print(idx_1.max(), idx_1.min())
# Out:
# 997721 73
# 999844 0

# %%
a = np.array([10,20,30,40,50,60])

# %%
a
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
a[np.array([3,0,2])]
# Out:
# array([40, 10, 30])
