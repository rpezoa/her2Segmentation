# %%
import numpy as np
from matplotlib import pyplot as plt
import sys
import os

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/rpezoa/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['show', 'clf']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
base_dir = "/home/rpezoa/experiment_data/"
images=["1+_20", "1+_25", "2+_1", "2+_8", "2+_9","3+_19"]
type_im = ["1+","1+","2+","2+","2+","3+"]
classifiers = ["deep_0_cross","svm_0","rf_0_cross", "extra_trees_0_cross", "knn_0_cross"]
crops_coord = [(767,742),(0,0),(20,387),(0,0),(414,414),(414,81)]
#classifiers = ["svm_0"]
#images=["1+_20"]
#type_im = ["1+"]
#classifiers = ["rf_0_cross"]

# %%
rows_b=1000
cols_b=1000
show = False
deltax = 200
deltay= 200
methods=["halton_patches","random_patches", "stratified_random"]
#methods=["random_patches"]
#methods = ["stratified_random"]
for meth in methods:
    if meth == "stratified_random":
        classifiers = ["deep_0_cross","svm_0_cross","rf_0_cross", "extra_trees_0_cross", "knn_0_cross"]

    m = np.load(base_dir + "output/" + meth + "_best_seeds.npy") #rows are the images, cols are the classifiers
    rows,cols = m.shape
    for i in range(rows):
        print(images[i])
        for j in range(cols):
            clf = classifiers[j]
            print(clf)
            best_seed = m[i,j]
            path1= base_dir + "output/" + images[i] + "_rpr_" + meth + "/"+ clf + "/" + str(int(best_seed)) + "_pred_3.png"
            print(path1)
            #if os.path.exists(path1):
            current_im = plt.imread(path1)
            #else:
            #    current_im = plt.imread(base_dir + "output/" + images[i] + "_rpr_" + meth + "/"+ clf + "/" + str(int(best_seed)) + ".png")
            print(current_im.shape)
            x,y = crops_coord[i]
            print(x,deltax,y,deltay)
            crop = current_im[x:x+deltax,y:y+deltay,0:3]
            path2 = base_dir + "output/" + images[i] + "_rpr_" + meth + "/"+ clf + "/" + str(int(best_seed)) + "_pred_" + str(x) + "_" + str(y) +  "_auto_3.png"
            #print(path2)
            print("crop.shape", crop.shape)
            plt.imsave(path2,crop)
# Out:
# 1+_20
# deep_0_cross
# /home/rpezoa/experiment_data/output/1+_20_rpr_halton_patches/deep_0_cross/4_pred_3.png
# (1000, 1000, 4)
# 767 200 742 200
# crop.shape (200, 200, 3)
# svm_0
# /home/rpezoa/experiment_data/output/1+_20_rpr_halton_patches/svm_0/5_pred_3.png
# (1000, 1000, 4)
# 767 200 742 200
# crop.shape (200, 200, 3)
# rf_0_cross
# /home/rpezoa/experiment_data/output/1+_20_rpr_halton_patches/rf_0_cross/0_pred_3.png
# (1000, 1000, 4)
# 767 200 742 200
# crop.shape (200, 200, 3)
# extra_trees_0_cross
# /home/rpezoa/experiment_data/output/1+_20_rpr_halton_patches/extra_trees_0_cross/1_pred_3.png
# (1000, 1000, 4)
# 767 200 742 200
# crop.shape (200, 200, 3)
# knn_0_cross
# /home/rpezoa/experiment_data/output/1+_20_rpr_halton_patches/knn_0_cross/0_pred_3.png
# (1000, 1000, 4)
# 767 200 742 200
# crop.shape (200, 200, 3)
# 1+_25
# deep_0_cross
# /home/rpezoa/experiment_data/output/1+_25_rpr_halton_patches/deep_0_cross/6_pred_3.png
# (1000, 1000, 4)
# 0 200 0 200
# ...
