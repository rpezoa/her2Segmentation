# %%
import numpy as np
from matplotlib import pyplot as plt

def show(im, c = "gray",title=""):
    plt.figure(figsize=(10,10))
    plt.imshow(im,cmap = c)
    plt.title(title)
    plt.axis("off")
    plt.show()

path = "/home/rpezoa/her2Segmentation/data/"
#f=["b_a0_d2_b3.avg",  "b_a0_d2_b4.avg", "b_a0_d2_b5.avg", "b_a0_d2_b6.avg"]
f=["b_a0_d2_b3.enth",  "b_a0_d2_b4.enth", "b_a0_d2_b5.enth", "b_a0_d2_b6.enth"]

for i in f:
    m = np.genfromtxt(path + i, delimiter=',')
    print(np.linalg.norm(m))
    show(m, title=i)
# Out:
# 4923.41675301
# 5426.54064266
# 5790.54150415
# 6069.71562573
